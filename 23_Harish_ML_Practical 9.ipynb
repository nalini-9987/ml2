# %% [markdown]
# # Aim : Demonstrate kernelization in SVM to deal with non-linear data.

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from mpl_toolkits import mplot3d
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from matplotlib.colors import ListedColormap

# %%
from sklearn.datasets import make_circles
X, y = make_circles(100, factor = .1, noise = .1)
plt.scatter(X[:,0],X[:,1],c = y, s = 50, cmap = 'bwr')

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
classifier = SVC(kernel = "linear")
classifier.fit(X_train,y_train.ravel())
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X,y,clf = classifier, legend = 2)
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
def plot_3d_plot(X,y):
    r = np.exp(-(X ** 2).sum(1))
    ax = plt.subplot(projection = '3d')
    ax.scatter3D(X[:,0],X[:,1],r,c = y,s = 100,cmap = 'bwr')
    ax.set_xlabel('X1')
    ax.set_ylabel('X2')
    ax.set_zlabel('y')
    return ax

# %%
plot_3d_plot(X,y)

# %%
rbf_classifier = SVC(kernel = "rbf")
rbf_classifier.fit(X_train,y_train)
y_pred = rbf_classifier.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
plot_decision_regions(X,y,rbf_classifier)
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
poly_classifier = SVC(kernel = "poly",degree = 2)
poly_classifier.fit(X_train,y_train)
y_pred = poly_classifier.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
plot_decision_regions(X,y,poly_classifier)
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
X
# Out:
# array([[-9.19938462e-01, -6.11738779e-01],
#        [ 8.96172158e-01,  7.55852507e-01],
#        [ 2.04463465e-01, -1.41579143e-01],
#        [-1.53679871e-01,  1.29493813e-01],
#        [-8.77882615e-01,  6.86556251e-01],
#        [ 6.58137952e-02, -3.16189432e-02],
#        [-3.67816206e-01,  1.10104090e+00],
#        [-8.45419982e-02,  1.71154331e-01],
#        [-2.98963816e-01, -1.04958347e+00],
#        [-1.53009415e-01,  1.91670875e-02],
#        [ 9.62526556e-02, -7.94413691e-03],
#        [ 1.85817641e-02, -1.08378190e+00],
#        [ 5.67025229e-01, -1.06822384e+00],
#        [ 6.11860066e-03,  1.41496740e-02],
#        [ 5.62383257e-02, -2.64371927e-01],
#        [ 3.02263976e-02,  1.16450760e-01],
#        [ 8.98665970e-01, -4.80975579e-01],
#        [-9.88141382e-01,  1.92292061e-01],
#        [-6.15558730e-02, -5.83039972e-02],
#        [ 3.52226374e-02, -2.10469818e-01],
#        [-8.13288386e-02, -3.48446802e-04],
#        [ 2.79785440e-02,  4.24623832e-02],
# ...

# %%
X_new = np.exp(-(X**2))
X_new
# Out:
# array([[0.42900497, 0.68782259],
#        [0.44792721, 0.56478338],
#        [0.95905648, 0.9801549 ],
#        [0.97665921, 0.98337116],
#        [0.4626993 , 0.62415316],
#        [0.99567791, 0.99900074],
#        [0.87346365, 0.29751487],
#        [0.99287813, 0.9711311 ],
#        [0.91449858, 0.33233046],
#        [0.97686005, 0.99963269],
#        [0.99077821, 0.99993689],
#        [0.99965478, 0.30894772],
#        [0.72504786, 0.31946672],
#        [0.99996256, 0.99979981],
#        [0.99684225, 0.93249404],
#        [0.99908678, 0.98653075],
#        [0.44592677, 0.79347162],
#        [0.37665584, 0.96369904],
#        [0.99621804, 0.99660642],
#        [0.99876014, 0.95666926],
#        [0.99340745, 0.99999988],
#        [0.99921751, 0.99819857],
#        [0.98525048, 0.99853395],
#        [0.54299501, 0.56795446],
#        [0.40892759, 0.92060862],
#        [0.59637293, 0.4973293 ],
#        [0.98822323, 0.98960169],
#        [0.9964838 , 0.96898516],
# ...

# %%
plt.scatter(X_new[:,0],X_new[:,1],c = y,s = 100,cmap = 'bwr')

# %%
poly_classifier = SVC(kernel = "poly", degree = 2)
poly_classifier.fit(X_new,y)
y_pred = poly_classifier.predict(X_new)

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_new,y,clf = poly_classifier, legend = 2)
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
